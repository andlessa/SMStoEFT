# %% [markdown]
# # Plot

# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
import numpy as np
import pandas as pd
import glob,os,shutil
from pandas.io.json import json_normalize
import pyslha
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from collections import OrderedDict
import seaborn as sns
from scipy.interpolate import interp1d
from IPython.display import display, Markdown
import pylhe, gzip, tempfile

pd.option_context('display.max_columns', -1)

pd.options.mode.chained_assignment = None #Disable copy warnings
# plt.style.use('fivethirtyeight') #Set style
# mpl.rcParams.update({'figure.figsize' : (15,10)})  #Set general plotting options
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.cm.get_cmap('RdYlBu')

# %%
# files = {'SM': '../processFolders/topeft_eftLimit/qq2tt_bornOnly/Events/run_01/unweighted_events.lhe.gz', 
#          '1-loop  ($y_{DM} = 1$)' : '../processFolders/top_formFactors/qq2tt_bsmOnly/Events/run_03/unweighted_events.lhe.gz',
#          'EFT ($y_{DM} = 1$)' : '../processFolders/topeft_eftLimit/qq2tt_bsmOnly/Events/run_03/unweighted_events.lhe.gz'
#          }

files = {r'SM ($\bar{q} q \to \bar{t} t$)': '../processFolders/sms_nlo/qq2tt_sm_lo/Events/run_01/unweighted_events.lhe.gz', 
         r'1-loop  ($\bar{q} q \to \bar{t} t$)' : '../processFolders/top_formFactors/qq2tt_onlyInter/Events/run_01/unweighted_events.lhe.gz',
         r'EFT ($\bar{q} q \to \bar{t} t$)' : '../processFolders/topeft_eftLimit/qq2tt_onlyInter/Events/run_01/unweighted_events.lhe.gz',
         r'SM ($g g \to \bar{t} t$)': '../processFolders/sms_nlo/gg2tt_sm_lo/Events/run_01/unweighted_events.lhe.gz', 
         r'1-loop ($g g \to \bar{t} t$)' : '../processFolders/top_formFactors/gg2tt_onlyInter/Events/run_01/unweighted_events.lhe.gz',
         r'EFT ($g g \to \bar{t} t$)' : '../processFolders/topeft_eftLimit/gg2tt_onlyInter/Events/run_01/unweighted_events.lhe.gz',
         }

# %%
# It is necessary to remove the < signs from the LHE files (in the generate line) before parsing with pylhe
events = {}
for label, fpath in files.items():
    fixedFile = tempfile.mkstemp(suffix='.lhe')
    os.close(fixedFile[0])
    fixedFile = fixedFile[1]
    with  gzip.open(fpath,'rt') as f:
        data = f.readlines()
        with open(fixedFile,'w') as newF:
            for l in data:
                if 'generate' in l:
                    continue
                newF.write(l)
        files[label] = fixedFile
    events[label] = pylhe.read_lhe_with_attributes(fixedFile)

# %%
mtt = {}
mcTotal = {mod : 0 for mod in events}
weightsDict = {mod : [] for mod in events}
for mod,r in events.items():
    pT1 = []
    pT2 = []
    mTT = []
    for iev,ev in enumerate(r):
        weightsDict[mod].append(ev.eventinfo.weight)
        mcTotal[mod] += 1
        for ptc in ev.particles:
            if abs(ptc.id) != 6: continue
            if ptc.id == 6:
                pA = np.array([ptc.px,ptc.py,ptc.pz,ptc.e])
            else:
                pB = np.array([ptc.px,ptc.py,ptc.pz,ptc.e])

        pT1.append(max(np.linalg.norm(pA[0:3]),np.linalg.norm(pB[0:3])))
        pT2.append(min(np.linalg.norm(pA[0:3]),np.linalg.norm(pB[0:3])))
        mTT.append(np.sqrt((pA[-1]+pB[-1])**2-np.linalg.norm(pA[0:3]+pB[0:3])**2))
    mtt[mod] = {'pT1' : pT1, 'pT2' : pT2, 'mTT' : mTT}

# %%
for mod,w in weightsDict.items():
    weightsDict[mod] = np.array(w)/mcTotal[mod]

# %%
colors = {label : sns.color_palette('deep')[i] for i,label in enumerate(mtt.keys())}
f, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(10,8))
plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)
bins = np.linspace(0.,2000.,25)
weights = {}

for mod in mtt:
    if 'g' in mod: continue
    w,b,_ = axarr[0].hist(mtt[mod]['mTT'],label=mod,bins=bins,
                          weights=[1./mcTotal[mod]]*len(mtt[mod]['mTT']),
                          density=False,histtype='step',linewidth=2,color=colors[mod])
    weights[mod]= w
    yError = np.sqrt(w/mcTotal[mod])
    
    axarr[0].errorbar((b[:-1]+b[1:])/2.,w,yerr = yError, marker = '.', elinewidth=1.0,
                 drawstyle = 'steps-mid',linewidth=0.0,color=colors[mod])

nSM,b = np.histogram(mtt[r'SM ($\bar{q} q \to \bar{t} t$)']['mTT'],weights=weightsDict[r'SM ($\bar{q} q \to \bar{t} t$)'],bins=bins)    
for mod,w in weights.items():
    if 'SM' in mod: continue
    if not 'q' in mod: continue
    nBSM,_ = np.histogram(mtt[mod]['mTT'],weights=np.abs(weightsDict[mod]),bins=bins)
    ratio = nBSM/nSM
    axarr[1].plot(b[:-1],ratio,linewidth=3.0,linestyle='--', 
                          label=mod,c=colors[mod])

    
    
axarr[0].set_yscale('log')
axarr[1].set_xlabel(r'$m_{t\bar{t}}$ (GeV)')
axarr[0].set_ylabel('Normalized Events')
axarr[1].set_ylabel(r'$N_{BSM}/N_{SM}$')
axarr[1].set_ylim(1e-5,1)
axarr[1].set_yscale('log')
axarr[1].grid()

axarr[0].legend(loc='lower left')
# axarr[1].legend()
axarr[0].set_title(r'$ q \bar{q} \to t \bar{t}$ (Parton Level), $m_{T} = 400$ GeV, $m_{\chi} = 100$ GeV')
plt.show()
# Out:
# /tmp/ipykernel_114439/3030864041.py:23: RuntimeWarning: invalid value encountered in divide
#   ratio = nBSM/nSM

# %%
colors = {label : sns.color_palette('deep')[i] for i,label in enumerate(mtt.keys())}
f, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(10,8))
plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)
bins = np.linspace(0.,2000.,25)
weights = {}

for mod in mtt:
    if 'q' in mod: continue
    w,b,_ = axarr[0].hist(mtt[mod]['mTT'],label=mod,bins=bins,
                          weights=[1./mcTotal[mod]]*len(mtt[mod]['mTT']),
                          density=False,histtype='step',linewidth=2,color=colors[mod])
    weights[mod]= w
    yError = np.sqrt(w/mcTotal[mod])
    
    axarr[0].errorbar((b[:-1]+b[1:])/2.,w,yerr = yError, marker = '.', elinewidth=1.0,
                 drawstyle = 'steps-mid',linewidth=0.0,color=colors[mod])

nSM,b = np.histogram(mtt[r'SM ($g g \to \bar{t} t$)']['mTT'],weights=weightsDict[r'SM ($g g \to \bar{t} t$)'],bins=bins)    
for mod,w in weights.items():
    if 'SM' in mod: continue
    if not 'g' in mod: continue
    nBSM,_ = np.histogram(mtt[mod]['mTT'],weights=np.abs(weightsDict[mod]),bins=bins)
    ratio = nBSM/nSM
    axarr[1].plot(b[:-1],ratio,linewidth=3.0,linestyle='-.', 
                          label=mod,c=colors[mod])

    
    
axarr[0].set_yscale('log')
axarr[1].set_xlabel(r'$m_{t\bar{t}}$ (GeV)')
axarr[0].set_ylabel('Normalized Events')
axarr[1].set_ylabel(r'$N_{BSM}/N_{SM}$')
axarr[1].set_ylim(1e-5,1)
axarr[1].set_yscale('log')
axarr[1].grid()

axarr[0].legend(loc='lower left')
# axarr[1].legend()
axarr[0].set_title(r'$ g \bar{g} \to t \bar{t}$ (Parton Level), $m_{T} = 400$ GeV, $m_{\chi} = 100$ GeV')
plt.show()
# Out:
# /tmp/ipykernel_114439/3701122535.py:23: RuntimeWarning: invalid value encountered in divide
#   ratio = nBSM/nSM

# %%
colors = {label : sns.color_palette('deep')[i] for i,label in enumerate(mtt.keys())}
f, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(10,8))
plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)
bins = np.linspace(0.,2000.,25)
weights = {}

for mod in mtt:
    if '1-loop' in mod: continue
    w,b,_ = axarr[0].hist(mtt[mod]['mTT'],label=mod,bins=bins,
                          weights=[1./mcTotal[mod]]*len(mtt[mod]['mTT']),
                          density=False,histtype='step',linewidth=2,color=colors[mod])
    weights[mod]= w
    yError = np.sqrt(w/mcTotal[mod])
    
    axarr[0].errorbar((b[:-1]+b[1:])/2.,w,yerr = yError, marker = '.', elinewidth=1.0,
                 drawstyle = 'steps-mid',linewidth=0.0,color=colors[mod])

nSM,b = np.histogram(mtt[r'SM ($\bar{q} q \to \bar{t} t$)']['mTT'],weights=weightsDict[r'SM ($\bar{q} q \to \bar{t} t$)'],bins=bins)    
for mod,w in weights.items():
    if '1-loop' in mod: continue
    if 'SM' in mod: continue
    if not 'q' in mod: continue
    nBSM,_ = np.histogram(mtt[mod]['mTT'],weights=np.abs(weightsDict[mod]),bins=bins)
    ratio = nBSM/nSM
    axarr[1].plot(b[:-1],ratio,linewidth=3.0,linestyle='--', 
                          label=mod,c=colors[mod])

nSM,b = np.histogram(mtt[r'SM ($g g \to \bar{t} t$)']['mTT'],weights=weightsDict[r'SM ($g g \to \bar{t} t$)'],bins=bins)    
for mod,w in weights.items():
    if '1-loop' in mod: continue
    if 'SM' in mod: continue
    if not 'g' in mod: continue
    nBSM,_ = np.histogram(mtt[mod]['mTT'],weights=np.abs(weightsDict[mod]),bins=bins)
    ratio = nBSM/nSM
    axarr[1].plot(b[:-1],ratio,linewidth=3.0,linestyle='-.', 
                          label=mod,c=colors[mod])
    
    
axarr[0].set_yscale('log')
axarr[1].set_xlabel(r'$m_{t\bar{t}}$ (GeV)')
axarr[0].set_ylabel('Normalized Events')
axarr[1].set_ylabel(r'$N_{BSM}/N_{SM}$')
axarr[1].set_ylim(1e-5,1)
axarr[1].set_yscale('log')
axarr[1].grid()

axarr[0].legend(loc='lower left')
# axarr[1].legend()
axarr[0].set_title(r'$ p \bar{p} \to t \bar{t}$ (Parton Level)')
plt.show()
# Out:
# /tmp/ipykernel_114439/3080336819.py:24: RuntimeWarning: invalid value encountered in divide
#   ratio = nBSM/nSM
# /tmp/ipykernel_114439/3080336819.py:34: RuntimeWarning: invalid value encountered in divide
#   ratio = nBSM/nSM

# %%
colors = {label : sns.color_palette('deep')[i] for i,label in enumerate(mtt.keys())}
f, axarr = plt.subplots(2,sharex=True, gridspec_kw = {'height_ratios':[2, 1]},figsize=(10,8))
plt.subplots_adjust(left=0.12, bottom=0.12, right=0.97, top=None, wspace=None, hspace=0.1)
bins = np.linspace(0.,2000.,25)
weights = {}

for mod in mtt:
    w,b,_ = axarr[0].hist(mtt[mod]['mTT'],label=mod,bins=bins,
                          weights=[1./mcTotal[mod]]*len(mtt[mod]['mTT']),
                          density=False,histtype='step',linewidth=2,color=colors[mod])
    weights[mod]= w
    yError = np.sqrt(w/mcTotal[mod])
    
    axarr[0].errorbar((b[:-1]+b[1:])/2.,w,yerr = yError, marker = '.', elinewidth=1.0,
                 drawstyle = 'steps-mid',linewidth=0.0,color=colors[mod])

nSM,b = np.histogram(mtt[r'SM ($\bar{q} q \to \bar{t} t$)']['mTT'],weights=weightsDict[r'SM ($\bar{q} q \to \bar{t} t$)'],bins=bins)    
for mod,w in weights.items():
    if 'SM' in mod: continue
    if not 'q' in mod: continue
    nBSM,_ = np.histogram(mtt[mod]['mTT'],weights=np.abs(weightsDict[mod]),bins=bins)
    ratio = nBSM/nSM
    axarr[1].plot(b[:-1],ratio,linewidth=3.0,linestyle='--', 
                          label=mod,c=colors[mod])

nSM,b = np.histogram(mtt[r'SM ($g g \to \bar{t} t$)']['mTT'],weights=weightsDict[r'SM ($g g \to \bar{t} t$)'],bins=bins)    
for mod,w in weights.items():
    if 'SM' in mod: continue
    if not 'g' in mod: continue
    nBSM,_ = np.histogram(mtt[mod]['mTT'],weights=np.abs(weightsDict[mod]),bins=bins)
    ratio = nBSM/nSM
    axarr[1].plot(b[:-1],ratio,linewidth=3.0,linestyle='-.', 
                          label=mod,c=colors[mod])
    
    
axarr[0].set_yscale('log')
axarr[1].set_xlabel(r'$m_{t\bar{t}}$ (GeV)')
axarr[0].set_ylabel('Normalized Events')
axarr[1].set_ylabel(r'$N_{BSM}/N_{SM}$')
axarr[1].set_ylim(1e-5,1)
axarr[1].set_yscale('log')
axarr[1].grid()

axarr[0].legend(loc='lower left')
# axarr[1].legend()
axarr[0].set_title(r'$ p \bar{p} \to t \bar{t}$ (Parton Level)')
plt.show()
# Out:
# /tmp/ipykernel_114439/3137574185.py:22: RuntimeWarning: invalid value encountered in divide
#   ratio = nBSM/nSM
# /tmp/ipykernel_114439/3137574185.py:31: RuntimeWarning: invalid value encountered in divide
#   ratio = nBSM/nSM
