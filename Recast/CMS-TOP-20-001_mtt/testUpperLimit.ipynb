# %%
from cms_top_20_001_Limits import computeULs
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.colormaps['RdYlBu']


pd.set_option('display.max_rows', 200)

# %%
inputFile = './pp2tt_formFactors_scan.pcl'
outputFile = './testSimple.pcl'
computeULs(inputFile,outputFile)
# Out:
# Computing upper limits: 100%||||||||||||||||||||||||||||||||||||||Time: 0:00:36

# %%
resSimple = pd.read_pickle('testSimple.pcl')
resSimple[['mST','mChi','yDM (95% C.L.)','$\Delta \chi^2$ (95% C.L.)']]
# Out:
#         mST    mChi  yDM (95% C.L.)  $\Delta \chi^2$ (95% C.L.)
# 0     300.0     5.0        4.319038                        3.84
# 1     300.0    50.0        4.423537                        3.84
# 2     300.0   100.0        4.737764                        3.84
# 3     300.0   150.0        5.128766                        3.84
# 4     300.0   200.0        5.553127                        3.84
# ..      ...     ...             ...                         ...
# 202  3000.0  2900.0       48.925261                        3.84
# 203  3000.0  2925.0       48.986216                        3.84
# 204  3000.0  2950.0       49.073446                        3.84
# 205  3000.0  2975.0       49.106000                        3.84
# 206  3000.0  2990.0       49.025422                        3.84
#
# [207 rows x 4 columns]

# %%
inputFile = './pp2tt_formFactors_scan.pcl'
outputFile = './testFull.pcl'
computeULs(inputFile,outputFile,full=True)
# Out:
# Computing upper limits: 100%||||||||||||||||||||||||||||||||||||||Time: 0:06:52

# %%
resFull= pd.read_pickle('testFull.pcl')
resFull[['mST','mChi','yDM (95% C.L.)','$\Delta \chi^2$ (95% C.L.)']]
# Out:
#         mST    mChi  yDM (95% C.L.)  $\Delta \chi^2$ (95% C.L.)
# 0     300.0     5.0        4.925418                    3.778275
# 1     300.0    50.0        5.039179                    3.776846
# 2     300.0   100.0        5.386963                    3.781043
# 3     300.0   150.0        5.810782                    3.773418
# 4     300.0   200.0        5.777783                    3.810101
# ..      ...     ...             ...                         ...
# 202  3000.0  2900.0       70.816199                    3.832675
# 203  3000.0  2925.0       70.784858                    3.832768
# 204  3000.0  2950.0       70.719547                    3.832784
# 205  3000.0  2975.0       70.559092                    3.832920
# 206  3000.0  2990.0       70.188851                    3.833119
#
# [207 rows x 4 columns]

# %%
z = resSimple['yDM (95% C.L.)']/resFull['yDM (95% C.L.)']
x = resFull['mST']
y = resFull['mChi']
dm = x-y
plt.scatter(x,dm,c=z,cmap=cm,s=30)
plt.colorbar(label=r'$y_{DM}^{max}$(simple)/$y_{DM}^{max}$(full)')
plt.xlabel(r'$m_T$ (GeV)')
plt.ylabel(r'$\Delta M$ (GeV)')
plt.xlim(250.,1550.)
# plt.yscale('log')
plt.show()

# %%
z = resSimple['yDM (95% C.L.)']
x = resFull['mST']
y = resFull['mChi']
dm = x-y
plt.scatter(x,dm,c=z,cmap=cm,s=30,vmin=5,vmax=20)
plt.colorbar(label=r'$y_{DM}^{max}$(simple)')
plt.xlabel(r'$m_T$ (GeV)')
plt.ylabel(r'$\Delta M$ (GeV)')
plt.xlim(250.,1550.)
# plt.yscale('log')
plt.show()

# %%
z = resFull['yDM (95% C.L.)']
x = resFull['mST']
y = resFull['mChi']
dm = x-y
plt.scatter(x,dm,c=z,cmap=cm,s=30,vmin=5,vmax=20)
plt.colorbar(label=r'$y_{DM}^{max}$(full)')
plt.xlabel(r'$m_T$ (GeV)')
plt.ylabel(r'$\Delta M$ (GeV)')
plt.xlim(250.,1550.)
# plt.yscale('log')
plt.show()
