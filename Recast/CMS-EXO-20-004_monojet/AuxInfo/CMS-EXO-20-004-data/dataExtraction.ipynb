# %%
import numpy as np
import pandas as pd
import os,sys
pd.set_option('display.max_rows', 200)

# %%
#sigTemplatesFile = './HEPData-ins1894408-v2-csv/Signaltemplates,DMsimp,spin-1,Monojet.csv'
#cutFlowFile = './HEPData-ins1894408-v2-csv/CutflowforMonojet,DM,spin-1mediator.csv'

sigTemplatesFile = './HEPData-ins1894408-v2-csv/Signaltemplates,DMsimp,spin-0,Monojet.csv'
cutFlowFile = './HEPData-ins1894408-v2-csv/CutflowforMonojet,DM,spin-0mediator.csv'

# sigTemplatesFile = './HEPData-ins1894408-v2-csv/Signaltemplates,ADD,Monojet.csv'
# cutFlowFile = './HEPData-ins1894408-v2-csv/CutflowforMonojet,ADD.csv'

# %%
# Try to evaluate data if possible
def myeval(s):
    s = s.replace('#:','')
    s = s.strip()
    s = s.replace(' ','')
    try:
        return eval(s)
    except (ValueError,NameError,SyntaxError):
        return s

# Set default column names    
def fixColumnLabel(c):

    newC = c[:]
    newC = newC.replace('Coupling type','Coupling')
    newC = newC.replace('Production mode','Mode')
    newC = newC.replace('[TeV]','')
    newC = newC.replace('#:','').replace(' ','')
    newC = newC.replace(',','')
    while newC[-1] == '_':
        newC = newC[:-1]
    
    return newC

def getDictFrom(block):
    
    blockDict = {}
    isBins = False
    for line in block.split('\n'):
        if 'Recoil (GeV),Recoil (GeV) LOW,Recoil (GeV) HIGH' in line:
            isBins = True
            continue
        elif 'Cut stage,Fraction of passing events' in line:
            continue
        if len(line.split(',')) < 2:
            continue
        
        values = line.split(',')
        if isBins:
            binErrorPlus = myeval(values[-2])
            binErrorMinus = myeval(values[-1])            
            values = values[1:4]
            values[0] = 'bin_'+values[0]
        columnName = '_'.join([v for v in values[:-1] if len(v.strip()) > 0])
        columnName = fixColumnLabel(columnName)
        val = myeval(values[-1])
        blockDict[columnName] = [val]
        if isBins:
            columnsNameErrorPlus = columnName+'_ErrorPlus'
            columnsNameErrorMinus = columnName+'_ErrorMinus'
            blockDict[columnsNameErrorPlus] = [binErrorPlus]
            blockDict[columnsNameErrorMinus] = [binErrorMinus]
        
    
    return blockDict

# %% [markdown]
# ### Get cut flow data

# %%
# Get blocks for each parameter point (it is assumed they are separated by the '#: Coupling' tag)
with open(cutFlowFile,'r') as f:
    data = f.read()
    for tag in ['#: Coupling','#: $M_{D}$ [TeV]']:
        if not tag in data:
            continue
        blocks = data.split(tag)
        for ib,b in enumerate(blocks):
            blocks[ib] = tag.replace('# :','')+b
        break
# Skip header
blocks = blocks[1:]

# Define data frame from first block:
df = pd.DataFrame(getDictFrom(blocks[0]))

# Add remaining blocks to dataframe
for b in blocks[1:]:
    newDF = pd.DataFrame(getDictFrom(b))
    df = pd.concat([df,newDF],ignore_index=True)

# %% [markdown]
# ### Get signal template data

# %%
# Get blocks for each parameter point (it is assumed they are separated by the '#: Coupling' tag)
with open(sigTemplatesFile,'r') as f:
    data = f.read()
    for tag in ['#: Coupling','#: d,']:
        if not tag in data:
            continue
        blocks = data.split(tag)
        for ib,b in enumerate(blocks):
            blocks[ib] = tag.replace('# :','')+b
        break
# Skip header
blocks = blocks[1:]

# Define data frame from first block:
dfB = pd.DataFrame(getDictFrom(blocks[0]))

# Add remaining blocks to dataframe
for b in blocks[1:]:
    newDF = pd.DataFrame(getDictFrom(b))
    dfB = pd.concat([dfB,newDF],ignore_index=True)

# %%
print(len(df),len(dfB))
# Out:
# 193 299

# %% [markdown]
# ### Make sure values are standardized

# %%
# Rename column to match dF
df.rename(columns={'$g_{\chi}$' : '$g_{DM}$', 'd' : '$d$'}, inplace=True)
dfB.rename(columns={'$g_{\chi}$' : '$g_{DM}$', 'd' : '$d$'}, inplace=True)
if not 'Mode' in df.columns:
    df['Mode'] = 'DM+QCDjets'
    dfB['Mode'] = 'DM+QCDjets'
if not 'Coupling' in df.columns:
    df['Coupling'] = 'ADD'
    dfB['Coupling'] = 'ADD'

# Rename values to match dF
df['Mode']=df['Mode'].replace({'$\chi\chi+j$' : 'DM+QCDjets', 
                               '$\\chi\\chi$+Z(qq)' : 'DM+Z(qq)',
                               '$\\chi\\chi$+W(qq)' : 'DM+W(qq)'})
df['Data-takingperiod']=df['Data-takingperiod'].replace({7 : 2017, 8 : 2018, 6 : 2016})
dfB['Data-takingperiod']=dfB['Data-takingperiod'].replace({7 : 2017, 8 : 2018, 6 : 2016})

df.rename(columns={'"$\Delta\phi(jet_p_{T}^{miss})>0.5$rad"' :  '$\Delta \phi (jet,p_{T}^{miss})>0.5$ rad',
                   '$\Deltap_{T}^{miss}$(PF-Calorimeter)$<0.5$rad' : '$\Delta p_{T}^{miss}$ (PF-Cal)$<0.5$ rad',
                  '"$\Delta\phi(\mathrm{PF}_\mathrm{Charged})<2.0$rad"' : '$\Delta \phi (\mathrm{PF}_\mathrm{Charged})<2.0$ rad'}, 
          inplace=True)
dfB.rename(columns={'"$\Delta\phi(jet_p_{T}^{miss})>0.5$rad"' :  '$\Delta \phi (jet,p_{T}^{miss})>0.5$ rad',
                    '$\Deltap_{T}^{miss}$(PF-Calorimeter)$<0.5$rad' : '$\Delta p_{T}^{miss}$ (PF-Cal)$<0.5$ rad',
                   '"$\Delta\phi(\mathrm{PF}_\mathrm{Charged})<2.0$rad"' : '$\Delta \phi (\mathrm{PF}_\mathrm{Charged})<2.0$ rad'}, 
          inplace=True)

# %% [markdown]
# ### Merge cut flow and signal template

# %%
commonColumns = list(set(df.columns).intersection(set(dfB.columns)))
print(commonColumns)

dfComb = pd.merge(df,dfB,on=commonColumns,how='right')

# Filter mojet only (it seems monov is also present for spin0)
dfComb = dfComb[dfComb['Mode'] == 'DM+QCDjets']

sortColumnsDict = {'Coupling' : False, 'Mode' : False, '$m_{med}$' : True,
               '$M_{D}$' : True,'$m_{DM}$' : True,'d' :True,'Data-takingperiod' : True}
sortColumns = [c for c in sortColumnsDict if c in dfComb.columns]
ascending = [v for c,v in sortColumnsDict.items() if c in dfComb.columns]
dfComb.sort_values(sortColumns,inplace=True,
              ascending=ascending)
# Out:
# ['$m_{med}$', 'Mode', '$m_{DM}$', 'Coupling', '$g_{q}$', '$g_{DM}$', 'Data-takingperiod']

# %% [markdown]
# ### Compute total cross-section

# %%
binCols = [c for c in dfComb.columns if ('bin_' in c and not 'Error' in c)]
# Add total yield column
# (total yield = sum over MET bins/pre-selection efficiency)
# dfComb['TotalYield'] = dfComb[binCols].sum(axis=1)/dfComb['$\Delta \phi (\mathrm{PF}_\mathrm{Charged})<2.0$ rad'] 
dfComb['TotalYield'] = dfComb[binCols].sum(axis=1)/dfComb['$\Delta \phi (\mathrm{PF}_\mathrm{Charged})<2.0$ rad']
# Add luminosity
luminosities = {2016: 36.0, 2017 : 41.5, 2018 : 59.7}
dfComb['Luminosity (1/fb)'] = 36.0
for dp, lum in luminosities.items():
    dfComb.loc[dfComb['Data-takingperiod'] == dp, 'Luminosity (1/fb)'] = lum
# Compute total cross-section (total yield/eff)
# for the corresponding luminosities
dfComb['Total xsec-pT150 (pb)'] = dfComb['TotalYield']/(1e3*dfComb['Luminosity (1/fb)'])
# Remove auxiliary columns:
dfComb.drop('TotalYield',axis='columns',inplace=True)

# %%
dfComb
# Out:
#          Coupling        Mode  $m_{med}$  $m_{DM}$  $g_{DM}$  $g_{q}$  \
# 54         Scalar  DM+QCDjets       10.0       1.0       1.0      1.0
# 154        Scalar  DM+QCDjets       10.0       1.0       1.0      1.0
# 253        Scalar  DM+QCDjets       10.0       1.0       1.0      1.0
# 55         Scalar  DM+QCDjets       10.0       4.0       1.0      1.0
# 155        Scalar  DM+QCDjets       10.0       4.0       1.0      1.0
# 254        Scalar  DM+QCDjets       10.0       4.0       1.0      1.0
# 56         Scalar  DM+QCDjets       10.0       6.0       1.0      1.0
# 156        Scalar  DM+QCDjets       10.0       6.0       1.0      1.0
# 255        Scalar  DM+QCDjets       10.0       6.0       1.0      1.0
# 68         Scalar  DM+QCDjets       50.0       1.0       1.0      1.0
# 168        Scalar  DM+QCDjets       50.0       1.0       1.0      1.0
# 267        Scalar  DM+QCDjets       50.0       1.0       1.0      1.0
# 69         Scalar  DM+QCDjets       50.0      20.0       1.0      1.0
# 169        Scalar  DM+QCDjets       50.0      20.0       1.0      1.0
# 268        Scalar  DM+QCDjets       50.0      20.0       1.0      1.0
# 70         Scalar  DM+QCDjets       50.0      22.0       1.0      1.0
# 170        Scalar  DM+QCDjets       50.0      22.0       1.0      1.0
# 269        Scalar  DM+QCDjets       50.0      22.0       1.0      1.0
# 71         Scalar  DM+QCDjets       50.0      28.0       1.0      1.0
# 171        Scalar  DM+QCDjets       50.0      28.0       1.0      1.0
# 270        Scalar  DM+QCDjets       50.0      28.0       1.0      1.0
# 50         Scalar  DM+QCDjets      100.0       1.0       1.0      1.0
# 150        Scalar  DM+QCDjets      100.0       1.0       1.0      1.0
# 249        Scalar  DM+QCDjets      100.0       1.0       1.0      1.0
# 51         Scalar  DM+QCDjets      100.0      40.0       1.0      1.0
# 151        Scalar  DM+QCDjets      100.0      40.0       1.0      1.0
# 250        Scalar  DM+QCDjets      100.0      40.0       1.0      1.0
# 52         Scalar  DM+QCDjets      100.0      45.0       1.0      1.0
# 152        Scalar  DM+QCDjets      100.0      45.0       1.0      1.0
# 251        Scalar  DM+QCDjets      100.0      45.0       1.0      1.0
# 53         Scalar  DM+QCDjets      100.0      55.0       1.0      1.0
# 153        Scalar  DM+QCDjets      100.0      55.0       1.0      1.0
# 252        Scalar  DM+QCDjets      100.0      55.0       1.0      1.0
# 57         Scalar  DM+QCDjets      200.0       1.0       1.0      1.0
# 157        Scalar  DM+QCDjets      200.0       1.0       1.0      1.0
# 256        Scalar  DM+QCDjets      200.0       1.0       1.0      1.0
# 58         Scalar  DM+QCDjets      300.0       1.0       1.0      1.0
# 158        Scalar  DM+QCDjets      300.0       1.0       1.0      1.0
# 257        Scalar  DM+QCDjets      300.0       1.0       1.0      1.0
# 59         Scalar  DM+QCDjets      350.0       1.0       1.0      1.0
# 159        Scalar  DM+QCDjets      350.0       1.0       1.0      1.0
# 258        Scalar  DM+QCDjets      350.0       1.0       1.0      1.0
# 60         Scalar  DM+QCDjets      400.0       1.0       1.0      1.0
# 160        Scalar  DM+QCDjets      400.0       1.0       1.0      1.0
# 259        Scalar  DM+QCDjets      400.0       1.0       1.0      1.0
# 61         Scalar  DM+QCDjets      450.0       1.0       1.0      1.0
# 161        Scalar  DM+QCDjets      450.0       1.0       1.0      1.0
# 260        Scalar  DM+QCDjets      450.0       1.0       1.0      1.0
# 63         Scalar  DM+QCDjets      500.0       1.0       1.0      1.0
# 163        Scalar  DM+QCDjets      500.0       1.0       1.0      1.0
# 262        Scalar  DM+QCDjets      500.0       1.0       1.0      1.0
# 67         Scalar  DM+QCDjets      500.0      50.0       1.0      1.0
# 167        Scalar  DM+QCDjets      500.0      50.0       1.0      1.0
# 266        Scalar  DM+QCDjets      500.0      50.0       1.0      1.0
# 62         Scalar  DM+QCDjets      500.0     150.0       1.0      1.0
# 162        Scalar  DM+QCDjets      500.0     150.0       1.0      1.0
# 261        Scalar  DM+QCDjets      500.0     150.0       1.0      1.0
# 64         Scalar  DM+QCDjets      500.0     200.0       1.0      1.0
# 164        Scalar  DM+QCDjets      500.0     200.0       1.0      1.0
# 263        Scalar  DM+QCDjets      500.0     200.0       1.0      1.0
# 65         Scalar  DM+QCDjets      500.0     225.0       1.0      1.0
# 165        Scalar  DM+QCDjets      500.0     225.0       1.0      1.0
# 264        Scalar  DM+QCDjets      500.0     225.0       1.0      1.0
# 66         Scalar  DM+QCDjets      500.0     275.0       1.0      1.0
# 166        Scalar  DM+QCDjets      500.0     275.0       1.0      1.0
# 265        Scalar  DM+QCDjets      500.0     275.0       1.0      1.0
# 72         Scalar  DM+QCDjets      600.0       1.0       1.0      1.0
# 172        Scalar  DM+QCDjets      600.0       1.0       1.0      1.0
# 271        Scalar  DM+QCDjets      600.0       1.0       1.0      1.0
# 73         Scalar  DM+QCDjets      700.0       1.0       1.0      1.0
# 173        Scalar  DM+QCDjets      700.0       1.0       1.0      1.0
# 272        Scalar  DM+QCDjets      700.0       1.0       1.0      1.0
# 74         Scalar  DM+QCDjets      800.0       1.0       1.0      1.0
# 174        Scalar  DM+QCDjets      800.0       1.0       1.0      1.0
# 273        Scalar  DM+QCDjets      800.0       1.0       1.0      1.0
# 4    Pseudoscalar  DM+QCDjets       10.0       1.0       1.0      1.0
# 104  Pseudoscalar  DM+QCDjets       10.0       1.0       1.0      1.0
# 203  Pseudoscalar  DM+QCDjets       10.0       1.0       1.0      1.0
# 5    Pseudoscalar  DM+QCDjets       10.0       4.0       1.0      1.0
# 105  Pseudoscalar  DM+QCDjets       10.0       4.0       1.0      1.0
# 204  Pseudoscalar  DM+QCDjets       10.0       4.0       1.0      1.0
# 6    Pseudoscalar  DM+QCDjets       10.0       6.0       1.0      1.0
# 106  Pseudoscalar  DM+QCDjets       10.0       6.0       1.0      1.0
# 205  Pseudoscalar  DM+QCDjets       10.0       6.0       1.0      1.0
# 18   Pseudoscalar  DM+QCDjets       50.0       1.0       1.0      1.0
# 118  Pseudoscalar  DM+QCDjets       50.0       1.0       1.0      1.0
# 217  Pseudoscalar  DM+QCDjets       50.0       1.0       1.0      1.0
# 19   Pseudoscalar  DM+QCDjets       50.0      20.0       1.0      1.0
# 119  Pseudoscalar  DM+QCDjets       50.0      20.0       1.0      1.0
# 218  Pseudoscalar  DM+QCDjets       50.0      20.0       1.0      1.0
# 20   Pseudoscalar  DM+QCDjets       50.0      22.0       1.0      1.0
# 120  Pseudoscalar  DM+QCDjets       50.0      22.0       1.0      1.0
# 219  Pseudoscalar  DM+QCDjets       50.0      22.0       1.0      1.0
# 21   Pseudoscalar  DM+QCDjets       50.0      28.0       1.0      1.0
# 121  Pseudoscalar  DM+QCDjets       50.0      28.0       1.0      1.0
# 220  Pseudoscalar  DM+QCDjets       50.0      28.0       1.0      1.0
# 0    Pseudoscalar  DM+QCDjets      100.0       1.0       1.0      1.0
# 100  Pseudoscalar  DM+QCDjets      100.0       1.0       1.0      1.0
# 199  Pseudoscalar  DM+QCDjets      100.0       1.0       1.0      1.0
# 1    Pseudoscalar  DM+QCDjets      100.0      40.0       1.0      1.0
# 101  Pseudoscalar  DM+QCDjets      100.0      40.0       1.0      1.0
# 200  Pseudoscalar  DM+QCDjets      100.0      40.0       1.0      1.0
# 2    Pseudoscalar  DM+QCDjets      100.0      45.0       1.0      1.0
# 102  Pseudoscalar  DM+QCDjets      100.0      45.0       1.0      1.0
# 201  Pseudoscalar  DM+QCDjets      100.0      45.0       1.0      1.0
# 3    Pseudoscalar  DM+QCDjets      100.0      55.0       1.0      1.0
# 103  Pseudoscalar  DM+QCDjets      100.0      55.0       1.0      1.0
# 202  Pseudoscalar  DM+QCDjets      100.0      55.0       1.0      1.0
# 7    Pseudoscalar  DM+QCDjets      200.0       1.0       1.0      1.0
# 107  Pseudoscalar  DM+QCDjets      200.0       1.0       1.0      1.0
# 206  Pseudoscalar  DM+QCDjets      200.0       1.0       1.0      1.0
# 8    Pseudoscalar  DM+QCDjets      300.0       1.0       1.0      1.0
# 108  Pseudoscalar  DM+QCDjets      300.0       1.0       1.0      1.0
# 207  Pseudoscalar  DM+QCDjets      300.0       1.0       1.0      1.0
# 9    Pseudoscalar  DM+QCDjets      350.0       1.0       1.0      1.0
# 109  Pseudoscalar  DM+QCDjets      350.0       1.0       1.0      1.0
# 208  Pseudoscalar  DM+QCDjets      350.0       1.0       1.0      1.0
# 10   Pseudoscalar  DM+QCDjets      400.0       1.0       1.0      1.0
# 110  Pseudoscalar  DM+QCDjets      400.0       1.0       1.0      1.0
# 209  Pseudoscalar  DM+QCDjets      400.0       1.0       1.0      1.0
# 11   Pseudoscalar  DM+QCDjets      450.0       1.0       1.0      1.0
# 111  Pseudoscalar  DM+QCDjets      450.0       1.0       1.0      1.0
# 210  Pseudoscalar  DM+QCDjets      450.0       1.0       1.0      1.0
# 13   Pseudoscalar  DM+QCDjets      500.0       1.0       1.0      1.0
# 113  Pseudoscalar  DM+QCDjets      500.0       1.0       1.0      1.0
# 212  Pseudoscalar  DM+QCDjets      500.0       1.0       1.0      1.0
# 17   Pseudoscalar  DM+QCDjets      500.0      50.0       1.0      1.0
# 117  Pseudoscalar  DM+QCDjets      500.0      50.0       1.0      1.0
# 216  Pseudoscalar  DM+QCDjets      500.0      50.0       1.0      1.0
# 12   Pseudoscalar  DM+QCDjets      500.0     150.0       1.0      1.0
# 112  Pseudoscalar  DM+QCDjets      500.0     150.0       1.0      1.0
# 211  Pseudoscalar  DM+QCDjets      500.0     150.0       1.0      1.0
# 14   Pseudoscalar  DM+QCDjets      500.0     200.0       1.0      1.0
# 114  Pseudoscalar  DM+QCDjets      500.0     200.0       1.0      1.0
# 213  Pseudoscalar  DM+QCDjets      500.0     200.0       1.0      1.0
# 15   Pseudoscalar  DM+QCDjets      500.0     225.0       1.0      1.0
# 115  Pseudoscalar  DM+QCDjets      500.0     225.0       1.0      1.0
# 214  Pseudoscalar  DM+QCDjets      500.0     225.0       1.0      1.0
# 16   Pseudoscalar  DM+QCDjets      500.0     275.0       1.0      1.0
# 116  Pseudoscalar  DM+QCDjets      500.0     275.0       1.0      1.0
# 215  Pseudoscalar  DM+QCDjets      500.0     275.0       1.0      1.0
# 22   Pseudoscalar  DM+QCDjets      600.0       1.0       1.0      1.0
# 122  Pseudoscalar  DM+QCDjets      600.0       1.0       1.0      1.0
# 221  Pseudoscalar  DM+QCDjets      600.0       1.0       1.0      1.0
# 23   Pseudoscalar  DM+QCDjets      700.0       1.0       1.0      1.0
# 123  Pseudoscalar  DM+QCDjets      700.0       1.0       1.0      1.0
# 222  Pseudoscalar  DM+QCDjets      700.0       1.0       1.0      1.0
# 24   Pseudoscalar  DM+QCDjets      800.0       1.0       1.0      1.0
# 124  Pseudoscalar  DM+QCDjets      800.0       1.0       1.0      1.0
# 223  Pseudoscalar  DM+QCDjets      800.0       1.0       1.0      1.0
# 265  ...                     0.001259                     -0.001259
# 72   ...                     0.035749                     -0.035749
# 172  ...                     0.046839                     -0.046839
# 271  ...                     0.052947                     -0.052947
# 73   ...                     0.023581                     -0.023581
# 173  ...                     0.029032                     -0.029032
# 272  ...                     0.037628                     -0.037628
# 74   ...                     0.014459                     -0.014459
# 174  ...                     0.017920                     -0.017920
# 273  ...                     0.026342                     -0.026342
# 4    ...                     0.757590                     -0.757590
# 104  ...                     0.424580                     -0.424580
# 203  ...                     0.792300                     -0.792300
# 5    ...                     0.537030                     -0.537030
# 105  ...                     0.609710                     -0.609710
# 204  ...                     0.972110                     -0.972110
# 6    ...                     0.049816                     -0.049816
# 106  ...                     0.067966                     -0.067966
# 205  ...                     0.099589                     -0.099589
# 18   ...                     0.506300                     -0.506300
# 118  ...                     0.304200                     -0.304200
# 217  ...                     0.476360                     -0.476360
# 19   ...                     0.463780                     -0.463780
# 119  ...                     0.613810                     -0.613810
# 218  ...                     0.666600                     -0.666600
# 20   ...                     0.461400                     -0.461400
# 120  ...                     0.513770                     -0.513770
# 219  ...                     1.063400                     -1.063400
# 21   ...                     0.038656                     -0.038656
# 121  ...                     0.055099                     -0.055099
# 220  ...                     0.069706                     -0.069706
# 0    ...                     0.402190                     -0.402190
# 100  ...                     0.327820                     -0.327820
# 199  ...                     0.952580                     -0.952580
# 1    ...                     0.517550                     -0.517550
# 101  ...                     0.492090                     -0.492090
# 200  ...                     0.612940                     -0.612940
# 2    ...                     0.539010                     -0.539010
# 102  ...                     0.397150                     -0.397150
# 201  ...                     0.383350                     -0.383350
# 3    ...                     0.025414                     -0.025414
# 103  ...                     0.021705                     -0.021705
# 202  ...                     0.047185                     -0.047185
# 7    ...                     0.406180                     -0.406180
# 107  ...                     0.448250                     -0.448250
# 206  ...                     0.526030                     -0.526030
# 8    ...                     0.268490                     -0.268490
# 108  ...                     0.469600                     -0.469600
# 207  ...                     0.715250                     -0.715250
# 9    ...                     0.286040                     -0.286040
# 109  ...                     0.459890                     -0.459890
# 208  ...                     0.622910                     -0.622910
# 10   ...                     0.160300                     -0.160300
# 110  ...                     0.196560                     -0.196560
# 209  ...                     0.364680                     -0.364680
# 11   ...                     0.148450                     -0.148450
# 111  ...                     0.156230                     -0.156230
# 210  ...                     0.243930                     -0.243930
# 13   ...                     0.099072                     -0.099072
# 113  ...                     0.093329                     -0.093329
# 212  ...                     0.190860                     -0.190860
# 17   ...                     0.094342                     -0.094342
# 117  ...                     0.122570                     -0.122570
# 216  ...                     0.136600                     -0.136600
# 12   ...                     0.093384                     -0.093384
# 112  ...                     0.112900                     -0.112900
# 211  ...                     0.145400                     -0.145400
# 14   ...                     0.066093                     -0.066093
# 114  ...                     0.078480                     -0.078480
# 213  ...                     0.119950                     -0.119950
# 15   ...                     0.061321                     -0.061321
# 115  ...                     0.045639                     -0.045639
# 214  ...                     0.100260                     -0.100260
# 16   ...                     0.004116                     -0.004116
# 116  ...                     0.004759                     -0.004759
# 215  ...                     0.006592                     -0.006592
# 212                     0.150380                     -0.150380
# 17                      0.075951                     -0.075951
# 117                     0.104160                     -0.104160
# 216                     0.141070                     -0.141070
# 12                      0.093879                     -0.093879
# 112                     0.088864                     -0.088864
# 211                     0.167240                     -0.167240
# 14                      0.065353                     -0.065353
# 114                     0.071794                     -0.071794
# 213                     0.115640                     -0.115640
# 15                      0.049464                     -0.049464
# 115                     0.061189                     -0.061189
# 214                     0.105800                     -0.105800
# 16                      0.003717                     -0.003717
# 116                     0.004486                     -0.004486
# 215                     0.006089                     -0.006089
# 22                      0.056775                     -0.056775
# 122                     0.052702                     -0.052702
# 221                     0.081716                     -0.081716
# 23                      0.036272                     -0.036272
# 123                     0.037139                     -0.037139
# 222                     0.055014                     -0.055014
# 24                      0.022047                     -0.022047
# 124                     0.022418                     -0.022418
# 223                     0.028866                     -0.028866
#
#      Luminosity (1/fb)  Total xsec-pT150 (pb)
# 54                36.0                    NaN
# 154               41.5               1.940543
# 253               59.7               1.955077
# 55                36.0                    NaN
# 155               41.5               1.952818
# 254               59.7               1.976468
# 56                36.0                    NaN
# 156               41.5               0.112943
# 255               59.7               0.114440
# 68                36.0                    NaN
# 168               41.5               1.679024
# 267               59.7               1.697179
# 69                36.0                    NaN
# 169               41.5               1.708663
# 268               59.7               1.725050
# 70                36.0                    NaN
# 170               41.5               1.715295
# 269               59.7               1.737535
# 71                36.0                    NaN
# 171               41.5               0.049856
# 270               59.7               0.050316
# 50                36.0                    NaN
# 150               41.5               1.300155
# 249               59.7               1.307144
# 51                36.0                    NaN
# 151               41.5               1.325442
# 250               59.7               1.337536
# 52                36.0                    NaN
# 152               41.5               1.329654
# 251               59.7                    NaN
# 53                36.0                    NaN
# 153               41.5               0.027425
# 252               59.7               0.027645
# 57                36.0                    NaN
# 157               41.5               0.739554
# 256               59.7               0.750223
# 58                36.0                    NaN
# 158               41.5               0.504576
# 257               59.7               0.511516
# 59                36.0                    NaN
# 159               41.5               0.499218
# 258               59.7               0.506411
# 60                36.0                    NaN
# 160               41.5               0.399685
# 259               59.7                    NaN
# 61                36.0                    NaN
# 161               41.5               0.270342
# 260               59.7               0.276563
# 63                36.0                    NaN
# 163               41.5               0.179210
# 262               59.7               0.182487
# 67                36.0                    NaN
# 167               41.5               0.175234
# 266               59.7               0.178578
# 62                36.0                    NaN
# 162               41.5               0.134140
# 261               59.7               0.136524
# 64                36.0                    NaN
# 164               41.5               0.079133
# 263               59.7               0.080825
# 65                36.0                    NaN
# 165               41.5                    NaN
# 264               59.7               0.039157
# 66                36.0                    NaN
# 166               41.5               0.000941
# 265               59.7               0.000960
# 72                36.0                    NaN
# 172               41.5               0.081467
# 271               59.7               0.083206
# 73                36.0                    NaN
# 173               41.5               0.039705
# 272               59.7               0.040347
# 74                36.0                    NaN
# 174               41.5               0.020592
# 273               59.7               0.020943
# 4                 36.0                    NaN
# 104               41.5               4.364631
# 203               59.7               4.395769
# 5                 36.0                    NaN
# 105               41.5               4.391365
# 204               59.7               4.411830
# 6                 36.0                    NaN
# 106               41.5               0.348244
# 205               59.7               0.352008
# 18                36.0                    NaN
# 118               41.5               3.806238
# 217               59.7               3.853074
# 19                36.0                    NaN
# 119               41.5               3.817692
# 218               59.7               3.855591
# 20                36.0                    NaN
# 120               41.5               3.801327
# 219               59.7               3.844089
# 21                36.0                    NaN
# 121               41.5               0.212019
# 220               59.7               0.213940
# 0                 36.0                    NaN
# 100               41.5               2.966272
# 199               59.7               2.998456
# 1                 36.0                    NaN
# 101               41.5               2.974679
# 200               59.7               3.016730
# 2                 36.0                    NaN
# 102               41.5               2.971002
# 201               59.7               3.007465
# 3                 36.0                    NaN
# 103               41.5               0.142203
# 202               59.7               0.142613
# 7                 36.0                    NaN
# 107               41.5               1.812468
# 206               59.7               1.829261
# 8                 36.0                    NaN
# 108               41.5               1.505122
# 207               59.7               1.529246
# 9                 36.0                    NaN
# 109               41.5               1.682038
# 208               59.7               1.719217
# 10                36.0                    NaN
# 110               41.5               0.812798
# 209               59.7               0.826395
# 11                36.0                    NaN
# 111               41.5               0.460352
# 210               59.7               0.467177
# 13                36.0                    NaN
# 113               41.5               0.278620
# 212               59.7               0.283225
# 17                36.0                    NaN
# 117               41.5               0.274595
# 216               59.7               0.280243
# 12                36.0                    NaN
# 112               41.5               0.240549
# 211               59.7               0.245857
# 14                36.0                    NaN
# 114               41.5               0.192834
# 213               59.7               0.196578
# 15                36.0                    NaN
# 115               41.5               0.148670
# 214               59.7               0.151912
# 16                36.0                    NaN
# 116               41.5               0.006538
# 215               59.7               0.006649
# 22                36.0                    NaN
# 122               41.5               0.116280
# 221               59.7               0.118664
# 23                36.0                    NaN
# 123               41.5               0.054702
# 222               59.7               0.055569
# 24                36.0                    NaN
# 124               41.5               0.027736
# 223               59.7               0.028243
#
# [150 rows x 93 columns]

# %%
massPairs = set([])
for i,row in dfComb.iterrows():
    if '$m_{med}$' in row:
        massPairs.add((row['$m_{DM}$'],row['$m_{med}$']))
    else:
        massPairs.add((row['$M_{D}$'],row['$d$']))
massPairs = sorted(list(massPairs))
print(len(massPairs))
print(massPairs)
# Out:
# 25
# [(1.0, 10.0), (1.0, 50.0), (1.0, 100.0), (1.0, 200.0), (1.0, 300.0), (1.0, 350.0), (1.0, 400.0), (1.0, 450.0), (1.0, 500.0), (1.0, 600.0), (1.0, 700.0), (1.0, 800.0), (4.0, 10.0), (6.0, 10.0), (20.0, 50.0), (22.0, 50.0), (28.0, 50.0), (40.0, 100.0), (45.0, 100.0), (50.0, 500.0), (55.0, 100.0), (150.0, 500.0), (200.0, 500.0), (225.0, 500.0), (275.0, 500.0)]

# %%
# Save to pickle file
pickleFile = os.path.basename(sigTemplatesFile).replace(',','_')
pickleFile = os.path.splitext(pickleFile)[0]
pickleFile = pickleFile.split('_',1)[1]
pickleFile = pickleFile+'_DF.pcl'
print('Saving to',pickleFile)
dfComb.to_pickle(pickleFile)
# Out:
# Saving to DMsimp_spin-0_Monojet_DF.pcl
